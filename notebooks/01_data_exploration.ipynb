# %% [markdown]
# ### US1: Data Exploration and Initial Load
# **Task:** Load raw GDSC datasets and verify environmental dependencies.
# **Authors:** Shaahid, Wasif, Aditya

# %%
import pandas as pd
import os

# Define paths relative to the /notebooks folder
raw_data_path = "../data/raw/"

print("Environment setup successful.")
