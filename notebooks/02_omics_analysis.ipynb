# %% [markdown]
# ### US2: Multi-Omic Overlap & Feasibility Analysis
# **Objective:** Identify the intersection of cell lines across different omics layers to determine the final training sample size.
#
# **Criteria:**
# 1. Calculate individual coverage per omic.
# 2. Apply the **10% Rule** (Exclude omics with <10% coverage).
# 3. Identify the "Golden Pairing" for the GNN model.
